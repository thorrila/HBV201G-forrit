# %% [markdown]
# <a href="https://colab.research.google.com/github/thorrila/HBV201G-forrit/blob/main/S2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import numpy as np
import io
import io
# !pip install gapminder
from gapminder import gapminder

# %%
#1.1 - Gapminder
highest_life_exp = gapminder.loc[
    gapminder["country"] == "Iceland", ["year", "lifeExp"]
].sort_values("lifeExp", ascending=False).iloc[0]

display(highest_life_exp)
# Out:
# year       2007.000
# lifeExp      81.757
# Name: 695, dtype: float64

# %%
#1.2 - Gapminder
gdp_1972 = gapminder.loc[gapminder["year"] == 1972, ["country", "gdpPercap"]]
display(gdp_1972)
# Out:
#                  country    gdpPercap
# 4            Afghanistan   739.981106
# 16               Albania  3313.422188
# 28               Algeria  4182.663766
# 40                Angola  5473.288005
# 52             Argentina  9443.038526
# ...                  ...          ...
# 1648             Vietnam   699.501644
# 1660  West Bank and Gaza  3133.409277
# 1672         Yemen, Rep.  1265.047031
# 1684              Zambia  1773.498265
# 1696            Zimbabwe   799.362176
#
# [142 rows x 2 columns]

# %%
#2.2 - Fasteignir

# %%
#3.1 - Púls
import pandas as pd
puls = pd.read_csv('https://raw.githubusercontent.com/edbook/haskoli-islands/befec4563e9d2ce6a3b8674561fbae9193fce2e6/pulsAll.csv', sep=';')

puls["year"] = pd.to_datetime(puls["dagsetning"], dayfirst=True).dt.year

puls.groupby(["namskeid", "aldur"])["haed"].mean()
# Out:
# namskeid  aldur
# LAN203    19       183.666667
#           20       176.833333
#           21       170.818182
#           22       173.967742
#           23       174.636364
#           24       172.692308
#           25       173.718750
#           26       170.888889
#           27       171.000000
#           28       163.000000
#           29       172.500000
#           32       178.000000
#           33       184.000000
#           35       183.000000
#           36       156.000000
#           37       181.000000
#           39       178.000000
#           40       171.000000
#           41       164.500000
#           43       157.000000
#           44       185.000000
#           47       175.000000
#           49       170.000000
#           50       191.000000
#           52       185.000000
#           54       160.000000
#           70       176.000000
# STAE209   19       178.866667
#           20       172.605769
#           21       174.156863
# ...

# %%
#3.2 - Púls
puls.groupby(["namskeid", "year"])["haed"].mean()
# Out:
# namskeid  year
# LAN203    2013    174.377358
#           2014    170.914062
#           2015    174.618182
# STAE209   2013    173.670213
#           2014    172.677273
#           2015    173.670213
# Name: haed, dtype: float64

# %%
#4.1 - gapminder
gapminder.loc[gapminder.groupby(["year", "continent"])["lifeExp"].idxmax()]
# Out:
#           country continent  year  lifeExp        pop     gdpPercap
# 1260      Reunion    Africa  1952   52.724     257700   2718.885295
# 240        Canada  Americas  1952   68.750   14785584  11367.161120
# 756        Israel      Asia  1952   65.390    1620914   4086.522128
# 1140       Norway    Europe  1952   72.670    3327728  10095.421720
# 1092  New Zealand   Oceania  1952   69.390    1994794  10556.575660
# 973     Mauritius    Africa  1957   58.089     609816   2034.037981
# 241        Canada  Americas  1957   69.960   17010154  12489.950060
# 757        Israel      Asia  1957   67.840    1944401   5385.278451
# 685       Iceland    Europe  1957   73.470     165110   9244.001412
# 61      Australia   Oceania  1957   70.330    9712569  10949.649590
# 974     Mauritius    Africa  1962   60.246     701016   2529.067487
# 242        Canada  Americas  1962   71.300   18985849  13462.485550
# 758        Israel      Asia  1962   69.390    2310904   7105.630706
# ...

# %%
#4.2 - gapminder
gapminder.groupby("country")["lifeExp"].apply(lambda x: x.diff(5).lt(0.01 * x.shift(5))).idxmax()
# Out:
# ('Botswana', 165)
